# %%
import pickle
import numpy as np
import gzip
import os

import matplotlib.pyplot as plt

mask_files = os.listdir("final_results/")

def evaluate(GT, comparison_file):
    predictions = dict()
    #Read in example masks
    with open(comparison_file, 'rb') as f:
        predictions.update(pickle.load(f))

    IoU = []
    Accuracy = []
    #print(predictions.keys())
    for k,gt_mask in GT.items():
        pred_mask = np.asarray(predictions[k])
        gt_mask = np.asarray([v for v in gt_mask.values()])

        #print(gt_mask.shape, pred_mask.shape)
        # plt.figure(figsize=(12, 6))

        # plt.subplot(1, 2, 1)
        # plt.imshow(gt_mask[2,...])
        # plt.subplot(1, 2, 2)
        # plt.imshow(pred_mask[2,...])
        # plt.show()


        #Calculate accuracy
        #print(np.sum(pred_mask), np.sum(gt_mask))
        Accuracy += [np.sum(pred_mask == gt_mask)/pred_mask.size] 

        #Calculate IoU
        intersection = np.sum((pred_mask == 1) & (gt_mask == 1))
        union = np.sum((pred_mask == 1) | (gt_mask == 1))
        IoU += [intersection / union if union != 0 else 0]

    print("{0}, {2}, {1}, {4}, {3}".format(comparison_file,np.average(np.asarray(IoU)), np.average(np.asarray(Accuracy)), np.std(np.asarray(IoU)), np.std(np.asarray(Accuracy))))

#Read ground-truth masks
with gzip.open("ground_truth_masks/polarbear_GT_masks.pkl", 'rb') as f:
    PB_GT = pickle.load(f)
with gzip.open("ground_truth_masks/meerkat_GT_masks.pkl", 'rb') as f:
    MK_GT = pickle.load(f)

for file in mask_files:
    #print(file)
    if "polarbear" in file:
        evaluate(PB_GT, "final_results/"+file)
    else:
        evaluate(MK_GT, "final_results/"+file)
# Out:
# final_results/meerkat_DINOv2LDADINOv2_masks.pkl, 0.9141443020567602, 0.6196991780278842, 0.03842908637065099, 0.10717289742453628
# final_results/meerkat_DINOv2LDADINOv2_SAM_masks.pkl, 0.9435672034438776, 0.7314156823588692, 0.03859520924833465, 0.12001512238517123
# final_results/meerkat_DINOv2LDA_f0DINOv2_masks.pkl, 0.9141443020567602, 0.6196991780278842, 0.03842908637065099, 0.10717289742453628
# final_results/meerkat_DINOv2LDA_f0DINOv2_SAM_masks.pkl, 0.9486906688456633, 0.7523127214839614, 0.0419130644624296, 0.15154400687105282
# final_results/meerkat_DINOv2LDA_nmDINOv2_masks.pkl, 0.8501360411352039, 0.5075381672488463, 0.09202413178752808, 0.15228325297871023
# final_results/meerkat_DINOv2LDA_nmDINOv2_SAM_masks.pkl, 0.8831956413424744, 0.5970190214132745, 0.09254523015182885, 0.17915968199560128
# final_results/meerkat_DINOv2PCADINOv2_masks.pkl, 0.8675399394132652, 0.5546591943116949, 0.09366525988187585, 0.16179185395810394
# final_results/meerkat_DINOv2PCADINOv2_SAM_masks.pkl, 0.9043460817920916, 0.6703023717507378, 0.09589085379923144, 0.19704436105810863
# final_results/meerkat_DINOv2PCA_f0DINOv2_masks.pkl, 0.8675399394132652, 0.5546591943116949, 0.09366525988187585, 0.16179185395810394
# final_results/meerkat_DINOv2PCA_f0DINOv2_SAM_masks.pkl, 0.9124907724808673, 0.6948552120539756, 0.09502458512066567, 0.21696084953980802
# final_results/meerkat_DINOv2PCA_nmDINOv2_masks.pkl, 0.6687569256218111, 0.3849631398526751, 0.2530064683074761, 0.21654732351896142
# final_results/meerkat_DINOv2PCA_nmDINOv2_SAM_masks.pkl, 0.73754248046875, 0.4909334580050271, 0.26303510035560757, 0.26134188929136704
# final_results/meerkat_vid_SAM_box_masks.pkl, 0.9737092434630101, 0.8409668087411712, 0.016152489194304613, 0.08384532601783701
# final_results/polarbears_DINOv2LDADINOv2_masks.pkl, 0.9319507633131378, 0.828668272259922, 0.027025715527458867, 0.044508526897558257
# final_results/polarbears_DINOv2LDADINOv2_SAM_masks.pkl, 0.9726392299107144, 0.9276852555845555, 0.013035007167004621, 0.029865614185728376
# final_results/polarbears_DINOv2LDA_f0DINOv2_masks.pkl, 0.9319507633131378, 0.828668272259922, 0.027025715527458867, 0.044508526897558257
# final_results/polarbears_DINOv2LDA_f0DINOv2_SAM_masks.pkl, 0.978380221619898, 0.9430403163565758, 0.011929026594631773, 0.02797907047623736
# final_results/polarbears_DINOv2LDA_nmDINOv2_masks.pkl, 0.9274434689891581, 0.8218013165518758, 0.03640471457374302, 0.05741876729372095
# final_results/polarbears_DINOv2LDA_nmDINOv2_SAM_masks.pkl, 0.971537468112245, 0.9258606113576733, 0.017767124679885844, 0.038817031330972196
# final_results/polarbears_DINOv2PCADINOv2_masks.pkl, 0.9230787328603314, 0.8131026451964609, 0.037248221495051, 0.060336117391072294
# final_results/polarbears_DINOv2PCADINOv2_SAM_masks.pkl, 0.9654205596301023, 0.9133079426931894, 0.0319999383243509, 0.05650843737066719
# final_results/polarbears_DINOv2PCA_f0DINOv2_masks.pkl, 0.9318324996014031, 0.8280811323140411, 0.02660804254021727, 0.04376054167447195
# final_results/polarbears_DINOv2PCA_f0DINOv2_SAM_masks.pkl, 0.9784681720344388, 0.9432543960623829, 0.011854044277883276, 0.027871605130849526
# final_results/polarbears_DINOv2PCA_nmDINOv2_masks.pkl, 0.9090296456473215, 0.794794580498766, 0.06655363976439589, 0.08617042181592835
# final_results/polarbears_DINOv2PCA_nmDINOv2_SAM_masks.pkl, 0.9567844088807398, 0.9012983453046999, 0.05707240937226448, 0.0839009964946342
# final_results/polarbears_vid_SAM_box_masks.pkl, 0.9687725306919641, 0.9303413774177769, 0.04770837856589611, 0.08132884538393698

# %%
import os
import shutil

# Define the source, destination, and target directories
# source_dir = "D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Frames/"  # Replace with your source directory path
# target_dir = "D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Meerkats_inputs/"  # Replace with your target directory path
# meerkat_gt_dir = "D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Meerkat_GT_final/"      # The "Meerkat_GT_final" directory

source_dir = "D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/PB_Frames_test/"  # Replace with your source directory path
target_dir = "D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/"  # Replace with your target directory path
meerkat_gt_dir = "D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/PB_GT_FinalNew/"      # The "Meerkat_GT_final" directory

# Make sure the target directory exists
os.makedirs(target_dir, exist_ok=True)

# Iterate through the ID folders in the Meerkat_GT_final folder
for folder_id in os.listdir(meerkat_gt_dir):
    folder_id_path = os.path.join(meerkat_gt_dir, folder_id)

    # Check if it's a folder
    if os.path.isdir(folder_id_path):
        # Construct the corresponding source folder path
        source_folder_path = os.path.join(source_dir, folder_id)

        # If the source folder exists, copy it to the target directory
        if os.path.exists(source_folder_path):
            target_folder_path = os.path.join(target_dir, folder_id)
            shutil.copytree(source_folder_path, target_folder_path)
            print(f"Copied {folder_id} to {target_folder_path}")
        else:
            print(f"Source folder {folder_id} does not exist.")
# Out:
# Copied 000_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_099
# Copied 000_101 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_101
# Copied 000_104 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_104
# Copied 000_107 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_107
# Copied 000_110 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_110
# Copied 000_113 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_113
# Copied 000_115 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_115
# Copied 000_118 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_118
# Copied 000_121 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/000_121
# Copied 001_085 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/001_085
# Copied 001_088 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/001_088
# Copied 001_091 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/001_091
# Copied 001_093 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/001_093
# Copied 001_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/001_096
# Copied 001_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/001_099
# Copied 001_102 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/001_102
# Copied 002_087 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_087
# Copied 002_089 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_089
# Copied 002_092 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_092
# Copied 002_095 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_095
# Copied 002_098 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_098
# Copied 002_101 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_101
# Copied 002_104 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_104
# Copied 002_106 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/002_106
# Copied 003_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_096
# Copied 003_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_099
# Copied 003_102 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_102
# Copied 003_105 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_105
# Copied 003_107 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_107
# Copied 003_110 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_110
# Copied 003_113 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_113
# Copied 003_116 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/003_116
# Copied 004_085 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/004_085
# Copied 004_088 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/004_088
# Copied 004_090 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/004_090
# Copied 004_093 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/004_093
# Copied 004_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/004_096
# Copied 004_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/004_099
# Copied 004_102 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/004_102
# Copied 005_086 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_086
# Copied 005_089 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_089
# Copied 005_092 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_092
# Copied 005_095 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_095
# Copied 005_098 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_098
# Copied 005_101 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_101
# Copied 005_103 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_103
# Copied 005_106 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/005_106
# Copied 006_088 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/006_088
# Copied 006_091 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/006_091
# Copied 006_094 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/006_094
# Copied 006_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/006_096
# Copied 006_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/006_099
# Copied 006_102 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/006_102
# Copied 006_105 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/006_105
# Copied 007_085 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/007_085
# Copied 007_088 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/007_088
# Copied 007_090 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/007_090
# Copied 007_093 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/007_093
# Copied 007_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/007_096
# Copied 007_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/007_099
# Copied 007_102 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/007_102
# Copied 008_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_096
# Copied 008_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_099
# Copied 008_102 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_102
# Copied 008_105 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_105
# Copied 008_108 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_108
# Copied 008_111 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_111
# Copied 008_113 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_113
# Copied 008_116 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_116
# Copied 008_119 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/008_119
# Copied 009_092 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/009_092
# Copied 009_095 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/009_095
# Copied 009_097 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/009_097
# Copied 009_100 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/009_100
# Copied 009_103 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/009_103
# Copied 009_106 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/009_106
# Copied 009_109 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/009_109
# Copied 010_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_096
# Copied 010_098 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_098
# Copied 010_101 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_101
# Copied 010_104 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_104
# Copied 010_107 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_107
# Copied 010_110 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_110
# Copied 010_112 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_112
# Copied 010_115 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_115
# Copied 010_118 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/010_118
# Copied 011_086 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/011_086
# Copied 011_089 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/011_089
# Copied 011_092 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/011_092
# Copied 011_094 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/011_094
# Copied 011_097 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/011_097
# Copied 011_100 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/011_100
# Copied 011_103 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/011_103
# Copied 012_082 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/012_082
# Copied 012_084 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/012_084
# Copied 012_087 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/012_087
# Copied 012_090 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/012_090
# Copied 012_093 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/012_093
# Copied 012_096 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/012_096
# Copied 012_099 to D:/Meerkat-Project-Vision-Transformer-Behaviour-Prediction/Dataset/Polarbear_inputs/012_099
